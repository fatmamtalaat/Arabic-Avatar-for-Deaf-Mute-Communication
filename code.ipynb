# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.4 🚀 Python-3.10.12 torch-2.0.0+cpu CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5359.4/8062.4 GB disk)

# %%
pip install gdown==v4.6.3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="R60j48X7QuPKlV2JSAuJ")
project = rf.workspace("rgb-arsl").project("rgb-arabic-alphabet-sign-language-aasl-dataset")
dataset = project.version(12).download("yolov8")
# Out:
# ...
#   Obtaining dependency information for roboflow from https://files.pythonhosted.org/packages/e5/0c/b5a94933f815630171f1ed555ca180325c80d34fc6a42dfb1de4618bfdae/roboflow-1.1.16-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for certifi==2023.7.22 from https://files.pythonhosted.org/packages/4c/dd/2234eab22353ffc7d94e8d13177aaa050113286e93e7b40eae01fbf7c3d9/certifi-2023.7.22-py3-none-any.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 3.8 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.4 MB/s eta 0:00:00
# ...
#   Obtaining dependency information for opencv-python-headless==4.8.0.74 from https://files.pythonhosted.org/packages/76/02/f128517f3ade4bb5f71e2afd8461dba70e3f466ce745fa1fd1fade9ad1b7/opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# ...

# %%
! pip install ultralytics
! pip install pycocotools

import pycocotools
from ultralytics import YOLO
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os
import yaml
import torch
import shutil
#import wandb

# %matplotlib inline
# Out:
# ...
#   Obtaining dependency information for pycocotools from https://files.pythonhosted.org/packages/ba/64/0451cf41a00fd5ac4501de4ea0e395b7d909e09d665e56890b5d3809ae26/pycocotools-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.2/426.2 kB 7.2 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import numpy as np
import os
import pandas as pd
import shutil

from shutil import unpack_archive
from subprocess import check_output
shutil.os.mkdir("/kaggle/working/RGB-Arabic-Alphabet-Sign-Language-(AASL)-dataset-12/val")
shutil.os.mkdir("/kaggle/working/RGB-Arabic-Alphabet-Sign-Language-(AASL)-dataset-12/val/images")
shutil.os.mkdir("/kaggle/working/RGB-Arabic-Alphabet-Sign-Language-(AASL)-dataset-12/val/labels")

# %%
shutil.os.mkdir("/kaggle/working/RGB-Arabic-Alphabet-Sign-Language-(AASL)-dataset-12/train1")
shutil.os.mkdir("/kaggle/working/RGB-Arabic-Alphabet-Sign-Language-(AASL)-dataset-12/train1/images")
shutil.os.mkdir("/kaggle/working/RGB-Arabic-Alphabet-Sign-Language-(AASL)-dataset-12/train1/labels")

# %%
import os
import random
import shutil

imgList = os.listdir('/kaggle/working/RGB-Arabic-Alphabet-Sign-Language-(AASL)-dataset-12/train/images')


#shuffling images
random.shuffle(imgList)

split = 0.2

train_path = '/kaggle/working/RGB-Arabic-Alphabet-Sign-Language-(AASL)-dataset-12/train1'
val_path = '/kaggle/working/RGB-Arabic-Alphabet-Sign-Language-(AASL)-dataset-12/val'

if os.path.isdir(train_path) == False:
    os.makedirs(train_path)
if os.path.isdir(val_path) == False:
    os.makedirs(val_path)

imgLen = len(imgList)
print("Images in total: ", imgLen)

train_images = imgList[: int(imgLen - (imgLen*split))]
val_images = imgList[int(imgLen - (imgLen*split)):]
print("Training images: ", len(train_images))
print("Validation images: ", len(val_images))

for imgName in train_images:
    og_path = os.path.join('/kaggle/working/RGB-Arabic-Alphabet-Sign-Language-(AASL)-dataset-12/train/images', imgName)
    target_path = os.path.join(train_path, imgName)

    shutil.copyfile(og_path, target_path)

    og_txt_path = os.path.join('/kaggle/working/RGB-Arabic-Alphabet-Sign-Language-(AASL)-dataset-12/train/labels', imgName.replace('.jpg', '.txt'))
    target_txt_path = os.path.join(train_path, imgName.replace('.jpg', '.txt'))

    shutil.copyfile(og_txt_path, target_txt_path)

for imgName in val_images:
    og_path = os.path.join('/kaggle/working/RGB-Arabic-Alphabet-Sign-Language-(AASL)-dataset-12/train/images', imgName)
    target_path = os.path.join(val_path, imgName)

    shutil.copyfile(og_path, target_path)

    og_txt_path = os.path.join('/kaggle/working/RGB-Arabic-Alphabet-Sign-Language-(AASL)-dataset-12/train/labels', imgName.replace('.jpg', '.txt'))
    target_txt_path = os.path.join(val_path, imgName.replace('.jpg', '.txt'))

    shutil.copyfile(og_txt_path, target_txt_path)


print("Done! ")
# Out:
# Images in total:  7534
# Training images:  6027
# Validation images:  1507
# Done!

# %%
#!gdown --id 1dac_3nzJJDlFwuI9ybYFusT_IOQWuNRZ

# %%
#!unzip -q /kaggle/working/RGBArabicAlphabetSignLanguageyolov8.zip

# %%
import os
import pandas as pd
import shutil
from os import listdir
 
# get the path or directory
folder_dir = "/kaggle/working/RGB-Arabic-Alphabet-Sign-Language-(AASL)-dataset-12/train1"
for images in os.listdir(folder_dir):
 
    # check if the image ends with png or jpg or jpeg
    if (images.endswith(".png") or images.endswith(".jpg")\
        or images.endswith(".jpeg")):
        # display
        #print(images)
        shutil.move( "/kaggle/working/RGB-Arabic-Alphabet-Sign-Language-(AASL)-dataset-12/train1/" + images, "/kaggle/working/RGB-Arabic-Alphabet-Sign-Language-(AASL)-dataset-12/train1/images")
    if (images.endswith(".txt")):
        # display
        #print(images)
        shutil.move( "/kaggle/working/RGB-Arabic-Alphabet-Sign-Language-(AASL)-dataset-12/train1/" + images, "/kaggle/working/RGB-Arabic-Alphabet-Sign-Language-(AASL)-dataset-12/train1/labels")

# %%
import os
import pandas as pd
import shutil
from os import listdir
 
# get the path or directory
folder_dir = "/kaggle/working/RGB-Arabic-Alphabet-Sign-Language-(AASL)-dataset-12/val"
for images in os.listdir(folder_dir):
 
    # check if the image ends with png or jpg or jpeg
    if (images.endswith(".png") or images.endswith(".jpg")\
        or images.endswith(".jpeg")):
        # display
        #print(images)
        shutil.move( "/kaggle/working/RGB-Arabic-Alphabet-Sign-Language-(AASL)-dataset-12/val/" + images, "/kaggle/working/RGB-Arabic-Alphabet-Sign-Language-(AASL)-dataset-12/val/images")
    if (images.endswith(".txt")):
        # display
        #print(images)
        shutil.move( "/kaggle/working/RGB-Arabic-Alphabet-Sign-Language-(AASL)-dataset-12/val/" + images, "/kaggle/working/RGB-Arabic-Alphabet-Sign-Language-(AASL)-dataset-12/val/labels")

# %%
#!gdown --id 1Sogt-oBMzVUxp9StZ4mNTLR8P8ayo2-u

# %%
# !gdown --id 1V5R4fLesixgkEU3VpqOOSW3rCcbVo97U
# Out:
# /opt/conda/lib/python3.10/site-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1V5R4fLesixgkEU3VpqOOSW3rCcbVo97U
# To: /kaggle/working/ASLdata.yaml
# 100%|██████████████████████████████████████████| 647/647 [00:00<00:00, 2.24MB/s]

# %%
# !yolo train model=yolov8s.pt data=/kaggle/working/ASLdata.yaml epochs=100 imgsz=480 batch=8
#!yolo train model=/kaggle/working/last.pt data=/kaggle/input/arabic-sign-language-unaugmented-dataset/unaugmented/416/data.yaml epochs=100 imgsz=640 batch=16
# Out:
# ...
# 100%|██████████████████████████████████████| 21.5M/21.5M [00:00<00:00, 48.7MB/s]
# Ultralytics YOLOv8.1.4 🚀 Python-3.10.12 torch-2.0.0+cpu CPU (Intel Xeon 2.20GHz)
# ...
